# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress


# Study data files
adp_path = "2019ADP.csv"
rushing_path = "2019fantasy_points.csv"

# Read the mouse data and the study results

adp_ = pd.read_csv(adp_path)
rushing_ = pd.read_csv(rushing_path)

# %%
rushing_.head()
# Out:
#         Player Pos  FantasyPoints
# 0  C.MCCAFFREY  RB         469.20
# 1    L.JACKSON  QB         415.68
# 2   D.PRESCOTT  QB         335.78
# 3     R.WILSON  QB         326.60
# 4     D.WATSON  QB         318.98

# %%
adp_.head()
# Out:
#                 Player First Name Second Name  ESPN
# 0       Saquon Barkley     Saquon     Barkley     1
# 1  Christian McCaffrey  Christian   McCaffrey     2
# 2         Alvin Kamara      Alvin      Kamara     3
# 3      Ezekiel Elliott    Ezekiel     Elliott     4
# 4      DeAndre Hopkins    DeAndre     Hopkins     5

# %%
adp_ = adp_.rename(columns={'Second Name':'Last Name'})

# %%
adp_.head()
# Out:
#                 Player First Name  Last Name  ESPN
# 0       Saquon Barkley     Saquon    Barkley     1
# 1  Christian McCaffrey  Christian  McCaffrey     2
# 2         Alvin Kamara      Alvin     Kamara     3
# 3      Ezekiel Elliott    Ezekiel    Elliott     4
# 4      DeAndre Hopkins    DeAndre    Hopkins     5

# %%
adp_ = adp_[['Last Name', 'First Name', 'ESPN']]

# %%
adp_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Last Name   148 non-null    object
#  1   First Name  148 non-null    object
#  2   ESPN        148 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.6+ KB

# %%
rushing_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         200 non-null    object
#  1   Pos            200 non-null    object
#  2   FantasyPoints  200 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 4.8+ KB

# %%
adp_['Last Name'] = adp_["Last Name"].str.upper()

# %%
adp_['Last Name'] = adp_['Last Name'].astype(str)

# %%
adp_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Last Name   148 non-null    object
#  1   First Name  148 non-null    object
#  2   ESPN        148 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.6+ KB

# %%
adp_['First Initial'] = adp_['First Name'].astype(str).str[0]

# %%
adp_.head()
# Out:
#    Last Name First Name  ESPN First Initial
# 0    BARKLEY     Saquon     1             S
# 1  MCCAFFREY  Christian     2             C
# 2     KAMARA      Alvin     3             A
# 3    ELLIOTT    Ezekiel     4             E
# 4    HOPKINS    DeAndre     5             D

# %%
adp_['Player'] = adp_[['First Initial', 'Last Name']].agg('.'.join, axis=1)

# %%
adp_.head()
# Out:
#    Last Name First Name  ESPN First Initial       Player
# 0    BARKLEY     Saquon     1             S    S.BARKLEY
# 1  MCCAFFREY  Christian     2             C  C.MCCAFFREY
# 2     KAMARA      Alvin     3             A     A.KAMARA
# 3    ELLIOTT    Ezekiel     4             E    E.ELLIOTT
# 4    HOPKINS    DeAndre     5             D    D.HOPKINS

# %%
new_adp_ = adp_[['Player', 'ESPN']]

# %%
new_adp_.head()
# Out:
#         Player  ESPN
# 0    S.BARKLEY     1
# 1  C.MCCAFFREY     2
# 2     A.KAMARA     3
# 3    E.ELLIOTT     4
# 4    D.HOPKINS     5

# %%
rushing_.head()
# Out:
#         Player Pos  FantasyPoints
# 0  C.MCCAFFREY  RB         469.20
# 1    L.JACKSON  QB         415.68
# 2   D.PRESCOTT  QB         335.78
# 3     R.WILSON  QB         326.60
# 4     D.WATSON  QB         318.98

# %%
new_df = pd.merge(rushing_, new_adp_, how='left', on='Player')

# %%
new_df.head(10)
# Out:
#         Player Pos  FantasyPoints   ESPN
# 0  C.MCCAFFREY  RB         469.20    2.0
# 1    L.JACKSON  QB         415.68  122.0
# 2   D.PRESCOTT  QB         335.78   89.0
# 3     R.WILSON  QB         326.60   93.0
# 4     D.WATSON  QB         318.98   38.0
# 5    E.ELLIOTT  RB         311.70    4.0
# 6     A.EKELER  RB         309.00   82.0
# 7      D.HENRY  RB         294.60   34.0
# 8       D.COOK  RB         292.40   20.0
# 9      J.ALLEN  QB         282.56    NaN

# %%
new_df = new_df.dropna(how='any')

# %% [markdown]
# Can do further analysis here:
#
# With those players that were not drafted, why was that the case?

# %%
new_df['ESPN'] = new_df['ESPN'].astype(int)

# %%
new_df.head()
# Out:
#         Player Pos  FantasyPoints  ESPN
# 0  C.MCCAFFREY  RB         469.20     2
# 1    L.JACKSON  QB         415.68   122
# 2   D.PRESCOTT  QB         335.78    89
# 3     R.WILSON  QB         326.60    93
# 4     D.WATSON  QB         318.98    38

# %%
#interesting to note here:

# %%
merged_inner
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, RushingPlayer, FantasyPoints, Full Name, First Name_x, Last Name, Player, First Name_y, ESPN]
# Index: []

# %%
# Combine the data into a single dataset
total_study_df = pd.merge(mouse_metadata, study_results, how='left', on='Mouse ID')

total_study_df.head(40)
# Display the data table for preview

# %%
clear_df = total_study_df

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
total_study_df.to_csv('study.csv', index=False)

# %%
total_study_df[20:30]
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 20     x401    Capomulin  Female          16          15          0
# 21     x401    Capomulin  Female          16          15          5
# 22     x401    Capomulin  Female          16          15         10
# 23     x401    Capomulin  Female          16          15         15
# 24     x401    Capomulin  Female          16          15         20
# 25     x401    Capomulin  Female          16          15         25
# 26     x401    Capomulin  Female          16          15         30
# 27     x401    Capomulin  Female          16          15         35
# 28     x401    Capomulin  Female          16          15         40
# 29     x401    Capomulin  Female          16          15         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 20           45.000000                 0
# 21           45.473753                 0
# 22           39.113891                 0
# 23           39.776250                 0
# ...

# %%
total_study_df.loc[total_study_df['Mouse ID'] == 'x401']
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 20     x401    Capomulin  Female          16          15          0
# 21     x401    Capomulin  Female          16          15          5
# 22     x401    Capomulin  Female          16          15         10
# 23     x401    Capomulin  Female          16          15         15
# 24     x401    Capomulin  Female          16          15         20
# 25     x401    Capomulin  Female          16          15         25
# 26     x401    Capomulin  Female          16          15         30
# 27     x401    Capomulin  Female          16          15         35
# 28     x401    Capomulin  Female          16          15         40
# 29     x401    Capomulin  Female          16          15         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 20           45.000000                 0
# 21           45.473753                 0
# 22           39.113891                 0
# 23           39.776250                 0
# ...

# %%
total_study_df.columns
# Out:
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)',
#        'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'],
#       dtype='object')

# %%
total_study_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1893 entries, 0 to 1892
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Mouse ID            1893 non-null   object
#  1   Drug Regimen        1893 non-null   object
#  2   Sex                 1893 non-null   object
#  3   Age_months          1893 non-null   int64
#  4   Weight (g)          1893 non-null   int64
#  5   Timepoint           1893 non-null   int64
#  6   Tumor Volume (mm3)  1893 non-null   float64
#  7   Metastatic Sites    1893 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 133.1+ KB

# %%
Filter = total_study_df['Timepoint'] == 45
total_study_df[Filter]
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9        k403     Ramicane    Male          21          16         45
# 19       s185    Capomulin  Female           3          17         45
# 29       x401    Capomulin  Female          16          15         45
# 39       m601    Capomulin    Male          22          17         45
# 49       g791     Ramicane    Male          11          16         45
# 59       s508     Ramicane    Male           1          17         45
# 74       m546     Ramicane    Male          18          16         45
# 84       z578     Ramicane    Male          11          16         45
# 94       j913     Ramicane  Female           4          17         45
# 104      u364    Capomulin    Male          18          17         45
# 114      n364     Ramicane    Male           4          17         45
# 124      y793    Capomulin    Male          17          17         45
# ...

# %%
total_study_df[Filter]
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9        k403     Ramicane    Male          21          16         45
# 19       s185    Capomulin  Female           3          17         45
# 29       x401    Capomulin  Female          16          15         45
# 39       m601    Capomulin    Male          22          17         45
# 49       g791     Ramicane    Male          11          16         45
# 59       s508     Ramicane    Male           1          17         45
# 74       m546     Ramicane    Male          18          16         45
# 84       z578     Ramicane    Male          11          16         45
# 94       j913     Ramicane  Female           4          17         45
# 104      u364    Capomulin    Male          18          17         45
# 114      n364     Ramicane    Male           4          17         45
# 124      y793    Capomulin    Male          17          17         45
# ...

# %%
total_study_df.describe()
#average for each column
# Out:
#         Age_months   Weight (g)    Timepoint  Tumor Volume (mm3)  \
# count  1893.000000  1893.000000  1893.000000         1893.000000
# mean     12.814580    25.662441    19.572108           50.448381
# std       7.189592     3.921622    14.079460            8.894722
# min       1.000000    15.000000     0.000000           22.050126
# 25%       7.000000    25.000000     5.000000           45.000000
# 50%      13.000000    27.000000    20.000000           48.951474
# 75%      20.000000    29.000000    30.000000           56.292200
# max      24.000000    30.000000    45.000000           78.567014
#
#        Metastatic Sites
# count       1893.000000
# mean           1.021659
# std            1.137974
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            2.000000
# max            4.000000

# %%
total_study_df.columns
# Out:
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)',
#        'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'],
#       dtype='object')

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html

# %%
#reveals duplicated DataFrame
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
#any mouse that has a value over 1
total_study_df[total_study_df.duplicated(['Mouse ID','Age_months','Timepoint'], keep=False)]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
len(total_study_df)
# Out:
# 1893

# %% [markdown]
# https://stackoverflow.com/questions/26244309/how-to-analyze-all-duplicate-entries-in-this-pandas-dataframe/33381151#33381151

# %%
# I want to drop g989 because this data has a duplicated time points

# %% [markdown]
# cleared, required to drop rows from the dataframe.

# %%
total_study_df = total_study_df.loc[total_study_df["Mouse ID"] != "g989", :]

# %%
total_study_df.to_csv('new_csv_dropped_g989.csv', index=False)

# %% [markdown]
# https://hackersandslackers.com/pandas-dataframe-drop/

# %%
len(total_study_df)
# Out:
# 1880

# %%
drug_groups = total_study_df.groupby('Drug Regimen')
drug_groups.count()
# Out:
#               Mouse ID  Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin          230  230         230         230        230
# Ceftamin           178  178         178         178        178
# Infubinol          178  178         178         178        178
# Ketapril           188  188         188         188        188
# Naftisol           186  186         186         186        186
# Placebo            181  181         181         181        181
# Propriva           148  148         148         148        148
# Ramicane           228  228         228         228        228
# Stelasyn           181  181         181         181        181
# Zoniferol          182  182         182         182        182
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin                    230               230
# Ceftamin                     178               178
# Infubinol                    178               178
# ...

# %%
#original dataFrame
len(mouse_metadata)
# Out:
# 249

# %%
merging = mouse_metadata.groupby('Drug Regimen')
# merging["Mouse ID"].sum()

# %%
total_study_df.columns
# Out:
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)',
#        'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'],
#       dtype='object')

# %%
check_for_error = total_study_df['Mouse ID']
check_for_error.sort_values()
check_for_error.value_counts()
len(check_for_error.value_counts())
#Number of Mice
# Out:
# 248

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
total_study_df = total_study_df[['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)', 'Tumor Volume (mm3)', 'Metastatic Sites', 'Timepoint']]

clean_study_df = total_study_df.drop_duplicates(subset=['Mouse ID'], keep='last')

# %%
clean_study_df = clean_study_df.reset_index(drop=True)

# %%
clean_study_df.to_csv('cleaned_df.csv', index=False)

# %% [markdown]
# ## Summary Statistics

# %%
clean_study_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Tumor Volume (mm3)  \
# 0       k403     Ramicane    Male          21          16           22.050126
# 1       s185    Capomulin  Female           3          17           23.343598
# 2       x401    Capomulin  Female          16          15           28.484033
# 3       m601    Capomulin    Male          22          17           28.430964
# 4       g791     Ramicane    Male          11          16           29.128472
# 5       s508     Ramicane    Male           1          17           30.276232
# 6       f966    Capomulin    Male          16          17           30.485985
# 7       m546     Ramicane    Male          18          16           30.564625
# 8       z578     Ramicane    Male          11          16           30.638696
# 9       j913     Ramicane  Female           4          17           31.560470
# 10      u364    Capomulin    Male          18          17           31.023923
# ...

# %% [markdown]
# get the summary statistic

# %%
clean_study_df.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Tumor Volume (mm3)  \
# 0     k403     Ramicane    Male          21          16           22.050126
# 1     s185    Capomulin  Female           3          17           23.343598
# 2     x401    Capomulin  Female          16          15           28.484033
# 3     m601    Capomulin    Male          22          17           28.430964
# 4     g791     Ramicane    Male          11          16           29.128472
#
#    Metastatic Sites  Timepoint
# 0                 1         45
# 1                 1         45
# 2                 0         45
# 3                 1         45
# 4                 1         45

# %%
male_female_df = pd.DataFrame(clean_study_df['Sex'].value_counts())

# %%
male_female_df
# Out:
#         Sex
# Male    125
# Female  124

# %%
male_female_df.plot(kind="pie", autopct="%1.1f%%", shadow=True, startangle=100, subplots=True)
plt.title("Mouse percentages between Male and Female")
# Out:
# Text(0.5, 1.0, 'Mouse percentages between Male and Female')

# %%
gender_df.plot(kind="pie", autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("Mouse percentages between Male and Female")

# %%
clean_study_df['Drug Regimen'].value_counts()
# Out:
# Zoniferol    25
# Ceftamin     25
# Infubinol    25
# Placebo      25
# Ramicane     25
# Capomulin    25
# Ketapril     25
# Propriva     25
# Naftisol     25
# Stelasyn     24
# Name: Drug Regimen, dtype: int64

# %%
grouped_drug_data = clean_study_df.groupby(['Drug Regimen'])

# %%
summary_df = pd.DataFrame(grouped_drug_data["Tumor Volume (mm3)"].describe())
summary_df.head()
# Out:
#               count       mean        std        min        25%        50%  \
# Drug Regimen
# Capomulin      25.0  36.667568   5.715188  23.343598  32.377357  38.125164
# Ceftamin       25.0  57.753977   8.365568  45.000000  48.722078  59.851956
# Infubinol      25.0  58.178246   8.602957  36.321346  54.048608  60.165180
# Ketapril       25.0  62.806191   9.945920  45.000000  56.720095  64.487812
# Naftisol       25.0  61.205757  10.297083  45.000000  52.079510  63.283288
#
#                     75%        max
# Drug Regimen
# Capomulin     40.159220  47.685963
# Ceftamin      64.299830  68.923185
# Infubinol     65.525743  72.226731
# Ketapril      69.872251  78.567014
# Naftisol      69.563621  76.668817

# %%
len(clean_study_df)
# Out:
# 249

# %%
sem = grouped_drug_data["Tumor Volume (mm3)"].sem()
sem.head()
# Out:
# Drug Regimen
# Capomulin    1.143038
# Ceftamin     1.673114
# Infubinol    1.720591
# Ketapril     1.989184
# Naftisol     2.059417
# Name: Tumor Volume (mm3), dtype: float64

# %%
#add a column to the dataFrame
summary_df['SEM'] = sem
# Out:
#               count       mean        std        min        25%        50%  \
# Drug Regimen
# Capomulin      25.0  36.667568   5.715188  23.343598  32.377357  38.125164
# Ceftamin       25.0  57.753977   8.365568  45.000000  48.722078  59.851956
# Infubinol      25.0  58.178246   8.602957  36.321346  54.048608  60.165180
# Ketapril       25.0  62.806191   9.945920  45.000000  56.720095  64.487812
# Naftisol       25.0  61.205757  10.297083  45.000000  52.079510  63.283288
# Placebo        25.0  60.508414   8.874672  45.000000  52.942902  62.030594
# Propriva       25.0  56.736964   8.327605  45.000000  49.122969  55.841410
# Ramicane       25.0  36.191390   5.671539  22.050126  31.560470  36.561652
# Stelasyn       24.0  61.001707   9.504293  45.000000  52.476596  62.192350
# Zoniferol      25.0  59.181258   8.767099  45.000000  49.988302  61.840058
#
#                     75%        max       SEM
# Drug Regimen
# Capomulin     40.159220  47.685963  1.143038
# ...

# %%
total_study_drop_df["Drug Regimen"].unique()
# Out:
# array(['Ramicane', 'Capomulin', 'Infubinol', 'Placebo', 'Ceftamin',
#        'Stelasyn', 'Zoniferol', 'Ketapril', 'Propriva', 'Naftisol'],
#       dtype=object)

# %%
# sem and std are the same.

# %%
df.groupby('A').agg({'B': ['min', 'max'], 'C': 'sum'})

# %%
#averages of the mean, median, variance, std, sem
clean_mean = summary_df['mean'].mean()
clean_median = summary_df['50%'].mean()
clean_std = summary_df['std'].mean()
clean_sem = summary_df['SEM'].mean()
mean_of_summary_df = pd.DataFrame({"Mean":[clean_mean],
                                   "Median":[clean_median],
                                   "Standard Deviation":[clean_std],
                                   "SEM":[clean_sem]})
mean_of_summary_df
# Out:
#         Mean     Median  Standard Deviation       SEM
# 0  55.023147  56.437947            8.407193  1.685358

# %% [markdown]
# # ValueError: If using all scalar values, you must pass an index
#
# https://stackoverflow.com/questions/17839973/constructing-pandas-dataframe-from-values-in-variables-gives-valueerror-if-usi

# %%
total_study_dro

# %%
df.groupby('A').agg({'B': ['min', 'max'], 'C': 'sum'})

# %%
clean_study_df.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Tumor Volume (mm3)  \
# 0     k403     Ramicane    Male          21          16           22.050126
# 1     s185    Capomulin  Female           3          17           23.343598
# 2     x401    Capomulin  Female          16          15           28.484033
# 3     m601    Capomulin    Male          22          17           28.430964
# 4     g791     Ramicane    Male          11          16           29.128472
#
#    Metastatic Sites  Timepoint
# 0                 1         45
# 1                 1         45
# 2                 0         45
# 3                 1         45
# 4                 1         45

# %%
summary_df = clean_study_df.groupby('Drug Regimen').agg({'Tumor Volume (mm3)': ['mean', 'min', 'max', 'std', 'var']})

# %%
clean_study_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b464a3e1fa7a> in <module>
# ----> 1 clean_study_df
#
# NameError: name 'clean_study_df' is not defined

# %%
summary_df.head(20)
# Out:
#              Tumor Volume (mm3)
#                            mean        min        max        std         var
# Drug Regimen
# Capomulin             36.667568  23.343598  47.685963   5.715188   32.663378
# Ceftamin              57.753977  45.000000  68.923185   8.365568   69.982735
# Infubinol             58.178246  36.321346  72.226731   8.602957   74.010875
# Ketapril              62.806191  45.000000  78.567014   9.945920   98.921330
# Naftisol              61.205757  45.000000  76.668817  10.297083  106.029927
# Placebo               60.508414  45.000000  73.212939   8.874672   78.759797
# Propriva              56.493884  45.000000  72.455421   8.415626   70.822755
# Ramicane              36.191390  22.050126  45.220869   5.671539   32.166354
# Stelasyn              61.001707  45.000000  75.123690   9.504293   90.331586
# Zoniferol             59.181258  45.000000  73.324432   8.767099   76.862027

# %% [markdown]
# # full summary of drug tumor sizes below

# %% [markdown]
# ## Bar and Pie Charts

# %%
drugs_per_mouse_df = total_study_drop_df.groupby(['Drug Regimen']).count()
drugs_per_mouse_df = drugs_per_mouse_df["Mouse ID"]
drugs_per_mouse_df
# Out:
# Drug Regimen
# Capomulin    25
# Ceftamin     25
# Infubinol    25
# Ketapril     25
# Naftisol     25
# Placebo      25
# Propriva     24
# Ramicane     25
# Stelasyn     24
# Zoniferol    25
# Name: Mouse ID, dtype: int64

# %%
# Creating dataset 
np.random.seed(10) 
  
data_1 = np.random.normal(100, 10, 200) 
data_2 = np.random.normal(90, 20, 200) 
data_3 = np.random.normal(80, 30, 200) 
data_4 = np.random.normal(70, 40, 200) 
data = [data_1, data_2, data_3, data_4]

# %%
len(data_1)
# Out:
# 200

# %%
data
# Out:
# [array([113.31586504, 107.15278974,  84.54599708,  99.9161615 ,
#         106.21335974,  92.79914439, 102.65511586, 101.08548526,
#         100.04291431,  98.25399789, 104.3302619 , 112.03037374,
#          90.34934329, 110.28274078, 102.2863013 , 104.45137613,
#          88.63397788, 101.35136878, 114.84537002,  89.20195114,
#          80.22271719,  82.56627704, 102.66070164, 123.84967331,
#         111.23691253, 116.72622213, 100.99149216, 113.97996377,
#          97.28752012, 106.13204185,  97.32682811,  94.50690986,
#         101.32708296,  95.23857985, 113.08473081, 101.95013279,
#         104.00209988,  96.62367663, 112.56472264,  92.68030498,
#         106.60231551,  96.49128109,  90.6056664 ,  95.10662783,
#          91.95408858,  97.87302361,  96.60859754, 103.12169936,
#         105.6515267 ,  98.52579742,  99.74094663, 102.89094204,
#          94.60120929, 107.0816002 , 108.42224738, 102.03580797,
#         123.94703665, 109.17458938,  98.87727529,  96.37819553,
# ...

# %%
drugs_per_mouse_new_df = drugs_per_mouse_df


drugs_per_mouse_new_df = drugs_per_mouse_new_df.reset_index()
drugs_per_mouse_new_df = drugs_per_mouse_new_df.rename(columns={"Mouse ID":"Number_of_Mice"})

# %%
drugs_per_mouse_new_df
# Out:
#   Drug Regimen  Number_of_Mice
# 0    Capomulin              25
# 1     Ceftamin              25
# 2    Infubinol              25
# 3     Ketapril              25
# 4     Naftisol              25
# 5      Placebo              25
# 6     Propriva              24
# 7     Ramicane              25
# 8     Stelasyn              24
# 9    Zoniferol              25

# %%
drugs_per_mouse_new_df.columns
# Out:
# Index(['Drug Regimen', 'Number_of_Mice'], dtype='object')

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
drugs_bar = drugs_per_mouse_new_df['Drug Regimen']
mouse_bar = drugs_per_mouse_new_df["Number_of_Mice"]
plt.figure(figsize=(20,3))
plt.bar(drugs_bar, mouse_bar, color='r', alpha = 0.5, align="edge")
plt.title('Number of Mice per Drug')
plt.xlabel('Drug')
plt.ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 

drugs_per_mouse_df.plot(kind="bar", figsize=(20,3), rot=45)
plt.title("Total Number of Mice per Drug")
plt.xlabel("Drug Name")
plt.ylabel("Number of Mice")
# Out:
# Text(0, 0.5, 'Number of Mice')

# %%
gender_df = total_study_drop_df.groupby(['Sex']).count()
gender_df = gender_df['Mouse ID']
gender_df
# Out:
# Sex
# Female    123
# Male      125
# Name: Mouse ID, dtype: int64

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas.
gender_df.plot(kind="pie", autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("Mouse percentages between Male and Female")
# Out:
# Text(0.5, 1.0, 'Mouse percentages between Male and Female')

# %%
#returning the index here

gender_df.index
# Out:
# Index(['Female', 'Male'], dtype='object', name='Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = gender_df.index
explode = (0.1, 0)
plt.pie(gender_df, explode=explode, labels=labels, autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("Mouse percentages between Male and Female")
# Out:
# Text(0.5, 1.0, 'Mouse percentages between Male and Female')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
drug_df = total_study_drop_df.groupby(['Drug Regimen']).mean()
drug_df
# Out:
#               Age_months  Weight (g)  Tumor Volume (mm3)  Metastatic Sites  \
# Drug Regimen
# Capomulin      14.040000   20.120000           36.667568          1.280000
# Ceftamin       12.800000   27.400000           57.753977          1.720000
# Infubinol      16.400000   27.320000           58.178246          1.600000
# Ketapril       14.720000   28.080000           62.806191          1.920000
# Naftisol       12.240000   27.240000           61.205757          2.000000
# Placebo        10.680000   28.040000           60.508414          2.080000
# Propriva        9.416667   27.291667           56.493884          1.541667
# Ramicane       10.840000   20.000000           36.191390          1.200000
# Stelasyn       13.125000   27.875000           61.001707          1.458333
# Zoniferol      12.600000   27.920000           59.181258          2.000000
#
#               Timepoint
# Drug Regimen
# Capomulin     41.000000
# Ceftamin      30.600000
# Infubinol     30.600000
# ...

# %% [markdown]
# I don't want to do a groupby I need to take a look at the dataframe

# %%
total_study_drop_df.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Tumor Volume (mm3)  \
# 0     k403     Ramicane    Male          21          16           22.050126
# 1     s185    Capomulin  Female           3          17           23.343598
# 2     x401    Capomulin  Female          16          15           28.484033
# 3     m601    Capomulin    Male          22          17           28.430964
# 4     g791     Ramicane    Male          11          16           29.128472
#
#    Metastatic Sites  Timepoint
# 0                 1         45
# 1                 1         45
# 2                 0         45
# 3                 1         45
# 4                 1         45

# %% [markdown]
# I would like to sort Drug Regimen, but doesn't matter

# %%
clean_study_df = clean_study_df.loc[(clean_study_df["Drug Regimen"] == "Capomulin") | (clean_study_df["Drug Regimen"] == "Ramicane") | (clean_study_df["Drug Regimen"] == "Infubinol") | (clean_study_df["Drug Regimen"] == "Ceftamin") , :]

# %%
clean_study_df[40:60]
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Tumor Volume (mm3)  \
# 40     r944    Capomulin    Male          12          25           41.581521
# 41     e662     Ramicane    Male           8          24           40.659006
# 42     u196     Ramicane    Male          18          25           40.667713
# 43     q597     Ramicane    Male          20          25           45.220869
# 44     a444     Ramicane  Female          10          25           43.047543
# 45     i557    Capomulin  Female           1          24           47.685963
# 46     r921     Ramicane  Female           5          25           43.419381
# 47     w678     Ramicane  Female           5          24           43.166373
# 48     y449     Ramicane    Male          19          24           44.183451
# 49     a203    Infubinol  Female          20          23           67.973419
# 50     a251    Infubinol  Female          21          25           65.525743
# ...

# %%
boxplot = clean_study_df.boxplot(by='Drug Regimen',column=['Tumor Volume (mm3)'])

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

#total_study_drop_df = total_study_df.drop_duplicates(subset=['Mouse ID'], keep='last')

#already dropped in the top cell.

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
drug_volume.head()
# Out:
#   Drug Regimen  Tumor Volume (mm3)
# 0     Ramicane           22.050126
# 1    Capomulin           23.343598
# 2    Capomulin           28.484033
# 3    Capomulin           28.430964
# 4     Ramicane           29.128472

# %%
drug_volume = total_study_drugs_df[['Drug Regimen', 'Tumor Volume (mm3)']]

# Capomulin, Ramicane, Infubinol, and Ceftamin

Ramicane = []
Capomulin = []
Infubinol = []
Ceftamin = []

for index, row in drug_volume.iterrows():
    if row['Drug Regimen'] == "Ramicane":
        Ramicane.append(row['Tumor Volume (mm3)'])
    if row['Drug Regimen'] == "Capomulin":
        Capomulin.append(row['Tumor Volume (mm3)'])
    if row['Drug Regimen'] == "Infubinol":
        Infubinol.append(row['Tumor Volume (mm3)'])
    if row['Drug Regimen'] == "Ceftamin":
        Ceftamin.append(row['Tumor Volume (mm3)'])

# %%
Infubinol = np.asarray(Infubinol)
Capomulin = np.asarray(Capomulin)
Ramicane = np.asarray(Ramicane)
Ceftamin = np.asarray(Ceftamin)

# %%
data_to_plot = [Infubinol, Capomulin, Ramicane, Ceftamin]

# %%
drug_volume_Infubinol = total_study_drop_df.loc[total_study_drop_df["Drug Regimen"] == "Infubinol"]
drug_volume_Infubinol

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

quartiles = drug_volume_Infubinol["Tumor Volume (mm3)"].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of tumor_size is: {lowerq}")
print(f"The upper quartile of tumor_size is: {upperq}")
print(f"The interquartile range of tumor_size is: {iqr}")
print(f"The the median of tumor_size is: {quartiles[0.5]} ")

    # Locate the rows which contain mice on each drug and get the tumor volumes
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
drug_volume_Infubinol.loc[drug_volume_Infubinol["Tumor Volume (mm3)"] < 36.832]
#this is a potential outlier

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %%
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot)

ax.set_xticklabels(["Infubinol", "Capomulin", "Ramicane", "Ceftamin"])

plt.title("BoxPlot for 4 Drugs")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

#use mouse s185

total_study_capomulin_df = total_study_df.loc[total_study_df["Mouse ID"] == "s185"]
total_study_capomulin_df
timepoint_capomulin = total_study_capomulin_df["Timepoint"]
tumor_size_capomulin = total_study_capomulin_df["Tumor Volume (mm3)"]
plt.title('Timepoint vs. Tumor Size for Capomulin')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Size')
plt.scatter(timepoint_capomulin, tumor_size_capomulin, marker="o", color="red")
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
total_study_capomulin_df = total_study_df.loc[total_study_df["Mouse ID"] == "s185"]
total_study_capomulin_df
weight_capomulin = total_study_capomulin_df["Weight (g)"]
tumor_size_capomulin = total_study_capomulin_df["Tumor Volume (mm3)"]
plt.title('Weight vs. Tumor Size for Capomulin')
plt.xlabel('Weight')
plt.ylabel('Tumor Size')
plt.scatter(weight_capomulin, tumor_size_capomulin, marker="o", color="red")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

correlation = st.pearsonr(timepoint_capomulin,tumor_size_capomulin)
print(f'correlation between time and tumor size is :{round(correlation[0],2)}')
print(line_eq)
x_values = timepoint_capomulin
y_values = tumor_size_capomulin
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(timepoint_capomulin, tumor_size_capomulin, marker="o", color="blue")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=10,color="red")
plt.xlabel('Timepoint')
plt.ylabel('Tumor Size')
plt.title('Timepoint vs. Tumor Size for Capomulin')
plt.show()
# Out:
# correlation between time and tumor size is :-0.98
# y = -0.47x + 45.16
